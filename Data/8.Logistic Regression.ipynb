# %% [markdown]
# # Logistic Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score, confusion_matrix

# %%
df=pd.DataFrame({
    "Study hours" : [15, 16, 13, 9, 8, 10, 8, 11],
    "Result": [1, 1, 1, 0, 0, 1, 1, 0]
})

# %%
df
# Out:
#    Study hours  Result
# 0           15       1
# 1           16       1
# 2           13       1
# 3            9       0
# 4            8       0
# 5           10       1
# 6            8       1
# 7           11       0

# %%
x= df[["Study hours"]]
y=df["Result"]

# %%
lr=LogisticRegression()
lr
# Out:
# LogisticRegression()

# %%
lr.predict(x)
# Out:
# array([1, 1, 1, 0, 0, 1, 0, 1])

# %%
lr.fit(x,y)
# Out:
# LogisticRegression()

# %%
lr.coef_
# Out:
# array([[0.43712459]])

# %%
lr.intercept_
# Out:
# array([-4.17049014])

# %%
predict=a.predict([[12.5]])
predict
# Out:
# C:\Users\nddha\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
plt.scatter(x,y, predict, label="datapoint")
plt.scatter(12.5,predict, color='red', label="Prediction")

plt.legend()
plt.xlabel("Study Hours")
plt.ylabel("Result")
plt.show()

# %%
x_line= np.linspace(1,25,100).reshape(-1, 1)
y_line=lr.predict_proba(x_line)[:, 1]
# Out:
# C:\Users\nddha\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(x,y)
plt.scatter(12.5, predict, label="prediction")
plt.plot(x_line, y_line, "r", label="S-Curve")
plt.legend()
plt.show()
