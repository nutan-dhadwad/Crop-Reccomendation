# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler

# %%
df= pd.read_csv(r"C:\Users\nddha\OneDrive\Desktop\ML\Data\cars.csv")
df.sample(10)
# Out:
#         brand  km_driven    fuel         owner  selling_price
# 3561     Tata     100000  Diesel   First Owner         250000
# 3398     Ford      40000  Petrol   First Owner         416000
# 2123  Hyundai      80000  Petrol  Second Owner         195000
# 4851   Toyota      24000  Diesel   First Owner        2064000
# 5045     Ford      50000  Diesel   First Owner         600000
# 6721  Renault     129000  Diesel   First Owner         650000
# 7877  Hyundai      20000  Petrol   First Owner         990000
# 1051   Maruti      20000  Petrol  Second Owner         250000
# 4390      BMW     102000  Diesel   First Owner        1100000
# 3206  Hyundai       5000  Petrol   First Owner         630000

# %%
SC_km= StandardScaler()
SC_km
# Out:
# StandardScaler()

# %%
df["km_driven"]= SC_km.fit_transform(df[["km_driven"]])

# %%
df.sample(10)
# Out:
#          brand  km_driven    fuel         owner  selling_price
# 7311   Hyundai   0.109298  Diesel   Third Owner         375000
# 5027  Mahindra   0.918871  Diesel   First Owner         532000
# 492     Maruti   0.003192  Diesel   First Owner         285000
# 1045    Toyota   0.533723  Diesel   First Owner         200000
# 8007   Hyundai   0.356879  Diesel  Second Owner         360000
# 2688   Hyundai  -0.757237  Diesel   First Owner        1050000
# 2528    Maruti  -0.403549  Petrol   First Owner         190000
# 6669      Ford   0.745936  Diesel  Second Owner         160000
# 1214   Hyundai   0.038561  Petrol   First Owner         320000
# 4507   Renault   3.009536  Diesel   First Owner         550000

# %%
SC_km.mean_
# Out:
# array([69819.51082677])

# %%
SC_km
# Out:
# StandardScaler()

# %%
Sp_minmax=MinMaxScaler()
df["selling_price"]=Sp_minmax.fit_transform(df[["selling_price"]])
df.sample(10)
# Out:
#         brand  km_driven    fuel                 owner  selling_price
# 7012  Hyundai   0.003192  Petrol           Third Owner       0.007021
# 4848   Maruti   0.180036  Petrol  Fourth & Above Owner       0.008024
# 5144   Maruti   0.356879  Petrol          Second Owner       0.008024
# 1896   Maruti  -0.173652  Diesel          Second Owner       0.057071
# 4380    Skoda  -0.651130  Petrol          Second Owner       0.157473
# 4301   Toyota  -0.173652  Petrol          Second Owner       0.032096
# 3125   Maruti   0.091614  Petrol           First Owner       0.012036
# 248    Maruti   0.887411  Diesel          Second Owner       0.047142
# 1916     Tata   0.256450  Diesel           First Owner       0.017051
# 6204   Maruti  -0.881027  Petrol           First Owner       0.013541

# %%
sp_mas= MaxAbsScaler()
df["selling_price"]= sp_mas.fit_transform(df[["selling_price"]])
df
# Out:
#         brand  km_driven    fuel                 owner  selling_price
# 0      Maruti   1.338363  Diesel           First Owner       0.042126
# 1       Skoda   0.887411  Diesel          Second Owner       0.034102
# 2       Honda   1.241098  Petrol           Third Owner       0.012839
# 3     Hyundai   1.011202  Diesel           First Owner       0.019559
# 4      Maruti   0.887411  Petrol           First Owner       0.010030
# ...       ...        ...     ...                   ...            ...
# 8123  Hyundai   0.710567  Petrol           First Owner       0.029087
# 8124  Hyundai   0.869726  Diesel  Fourth & Above Owner       0.010532
# 8125   Maruti   0.887411  Diesel           First Owner       0.035306
# 8126     Tata  -0.792605  Diesel           First Owner       0.026078
# 8127     Tata  -0.792605  Diesel           First Owner       0.026078
#
# [8128 rows x 5 columns]
