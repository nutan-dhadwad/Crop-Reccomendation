# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, OneHotEncoder

# %%
help(LabelEncoder)
# Out:
# Help on class LabelEncoder in module sklearn.preprocessing._label:
#
# class LabelEncoder(sklearn.base.TransformerMixin, sklearn.base.BaseEstimator)
#  |  Encode target labels with value between 0 and n_classes-1.
#  |
#  |  This transformer should be used to encode target values, *i.e.* `y`, and
#  |  not the input `X`.
#  |
#  |  Read more in the :ref:`User Guide <preprocessing_targets>`.
#  |
#  |  .. versionadded:: 0.12
#  |
#  |  Attributes
#  |  ----------
#  |  classes_ : ndarray of shape (n_classes,)
#  |      Holds the label for each class.
#  |
#  |  See Also
#  |  --------
#  |  OrdinalEncoder : Encode categorical features using an ordinal encoding
#  |      scheme.
#  |  OneHotEncoder : Encode categorical features as a one-hot numeric array.
#  |
#  |  Examples
#  |  --------
#  |  `LabelEncoder` can be used to normalize labels.
#  |
#  |  >>> from sklearn.preprocessing import LabelEncoder
#  |  >>> le = LabelEncoder()
#  |  >>> le.fit([1, 2, 2, 6])
#  |  LabelEncoder()
# ...

# %%
df= pd.read_csv(r"C:\Users\nddha\OneDrive\Desktop\ML\Data\customer.csv")
df.head()
# Out:
#    age  gender   review education purchased
# 0   30  Female  Average    School        No
# 1   68  Female     Poor        UG        No
# 2   70  Female     Good        PG        No
# 3   72  Female     Good        PG        No
# 4   16  Female  Average        UG        No

# %%
LE= LabelEncoder()
LE
# Out:
# LabelEncoder()

# %%
df["gender"]= LE.fit_transform(df["gender"])
df
# Out:
#     age  gender   review education purchased
# 0    30       0  Average    School        No
# 1    68       0     Poor        UG        No
# 2    70       0     Good        PG        No
# 3    72       0     Good        PG        No
# 4    16       0  Average        UG        No
# 5    31       0  Average    School       Yes
# 6    18       1     Good    School        No
# 7    60       0     Poor    School       Yes
# 8    65       0  Average        UG        No
# 9    74       1     Good        UG       Yes
# 10   98       0     Good        UG       Yes
# 11   74       1     Good        UG       Yes
# 12   51       1     Poor    School        No
# 13   57       0  Average    School        No
# 14   15       1     Poor        PG       Yes
# 15   75       1     Poor        UG        No
# 16   59       1     Poor        UG       Yes
# 17   22       0     Poor        UG       Yes
# 18   19       1     Good    School        No
# 19   97       1     Poor        PG       Yes
# ...

# %%
LE.classes_
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
LE
# Out:
# LabelEncoder()

# %%
LE_review=LabelEncoder()
df["review"]=LE_review.fit_transform(df["review"])
df
# Out:
#     age  gender  review education purchased
# 0    30       0       0    School        No
# 1    68       0       2        UG        No
# 2    70       0       1        PG        No
# 3    72       0       1        PG        No
# 4    16       0       0        UG        No
# 5    31       0       0    School       Yes
# 6    18       1       1    School        No
# 7    60       0       2    School       Yes
# 8    65       0       0        UG        No
# 9    74       1       1        UG       Yes
# 10   98       0       1        UG       Yes
# 11   74       1       1        UG       Yes
# 12   51       1       2    School        No
# 13   57       0       0    School        No
# 14   15       1       2        PG       Yes
# 15   75       1       2        UG        No
# 16   59       1       2        UG       Yes
# 17   22       0       2        UG       Yes
# 18   19       1       1    School        No
# 19   97       1       2        PG       Yes
# ...

# %%
LE_review.classes_
# Out:
# array(['Average', 'Good', 'Poor'], dtype=object)

# %%
OE_ed= OrdinalEncoder(categories=[["School","UG","PG"]])
df["education"]= OE_ed.fit_transform(df[["education"]])
df.head()
# Out:
#    age  gender  review  education purchased
# 0   30       0       0        0.0        No
# 1   68       0       2        1.0        No
# 2   70       0       1        2.0        No
# 3   72       0       1        2.0        No
# 4   16       0       0        1.0        No

# %%
OE_ed.categories_
# Out:
# [array(['School', 'UG', 'PG'], dtype=object)]

# %%
#OHE
#Get_Dummies

df= pd.get_dummies(data=df, columns=["purchased"]) * 1

# %%
df
# Out:
#     age  gender  review  education  purchased_No  purchased_Yes
# 0    30       0       0        0.0             1              0
# 1    68       0       2        1.0             1              0
# 2    70       0       1        2.0             1              0
# 3    72       0       1        2.0             1              0
# 4    16       0       0        1.0             1              0
# 5    31       0       0        0.0             0              1
# 6    18       1       1        0.0             1              0
# 7    60       0       2        0.0             0              1
# 8    65       0       0        1.0             1              0
# 9    74       1       1        1.0             0              1
# 10   98       0       1        1.0             0              1
# 11   74       1       1        1.0             0              1
# 12   51       1       2        0.0             1              0
# 13   57       0       0        0.0             1              0
# ...
