# %%
#to chech pip version
#pip --version   pip 25.2

#to create virtual environment
# python -m venv .env


#to activate virtual environment

#",env\Scripts\activate"


#to insta required packages
#pip install scikit-learn pandas numpy seaborn matplotlib streamlit --upgrade

# %%
#importing packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
df=pd.read_csv(r"C:\Users\nddha\OneDrive\Desktop\ML\ML Common Project\churn.csv").drop(["CustomerId","RowNumber", "Surname"], axis= 1)
df.head(10)
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
# 5          645     Spain    Male   44       8  113755.78              2
# 6          822    France    Male   50       7       0.00              2
# 7          376   Germany  Female   29       4  115046.74              4
# 8          501    France    Male   44       4  142051.07              2
# 9          684    France    Male   27       2  134603.88              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain  \
# 0          1               1        101348.88       1         1
# 1          0               1        112542.58       0         1
# 2          1               0        113931.57       1         1
# 3          0               0         93826.63       0         0
# 4          1               1         79084.10       0         0
# 5          1               0        149756.71       1         1
# 6          1               1         10062.80       0         0
# 7          1               0        119346.88       1         1
# 8          0               1         74940.50       0         0
# 9          1               1         71725.73       0         0
#
#    Satisfaction Score Card Type  Point Earned
# 0                   2   DIAMOND           464
# 1                   3   DIAMOND           456
# 2                   3   DIAMOND           377
# 3                   5      GOLD           350
# 4                   5      GOLD           425
# 5                   5   DIAMOND           484
# 6                   2    SILVER           206
# 7                   2   DIAMOND           282
# 8                   3      GOLD           251
# 9                   3      GOLD           342

# %%
newdf= pd.concat([df[df["Exited"]== 0].sample(2100), df[df["Exited"]== 1]], axis= 0, ignore_index=True)

# %%
newdf.to_csv(r"C:\Users\nddha\OneDrive\Desktop\ML\ML Common Project\Sampled_Churn.csv", index=False)

# %%
newdf.describe()
# Out:
#        CreditScore          Age       Tenure        Balance  NumOfProducts  \
# count  4138.000000  4138.000000  4138.000000    4138.000000    4138.000000
# mean    649.455534    40.831561     5.018850   81736.203323       1.506042
# std      97.390810    10.582247     2.904096   61354.906695       0.668058
# min     350.000000    18.000000     0.000000       0.000000       1.000000
# 25%     583.000000    33.000000     3.000000       0.000000       1.000000
# 50%     651.000000    40.000000     5.000000  103006.245000       1.000000
# 75%     718.000000    47.000000     8.000000  129292.800000       2.000000
# max     850.000000    88.000000    10.000000  250898.090000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary       Exited     Complain  \
# count  4138.000000     4138.000000      4138.000000  4138.000000  4138.000000
# mean      0.702755        0.459401    100773.863623     0.492508     0.491783
# std       0.457101        0.498409     58052.492734     0.500004     0.499993
# min       0.000000        0.000000        11.580000     0.000000     0.000000
# 25%       0.000000        0.000000     50791.070000     0.000000     0.000000
# 50%       1.000000        0.000000    102298.480000     0.000000     0.000000
# 75%       1.000000        1.000000    150827.010000     1.000000     1.000000
# max       1.000000        1.000000    199909.320000     1.000000     1.000000
#
#        Satisfaction Score  Point Earned
# count         4138.000000   4138.000000
# mean             2.981150    605.359594
# std              1.407062    224.069652
# min              1.000000    163.000000
# 25%              2.000000    407.000000
# 50%              3.000000    606.000000
# 75%              4.000000    798.000000
# max              5.000000   1000.000000

# %%
newdf.describe().round(2)
# Out:
#        CreditScore      Age   Tenure    Balance  NumOfProducts  HasCrCard  \
# count      4138.00  4138.00  4138.00    4138.00        4138.00    4138.00
# mean        649.46    40.83     5.02   81736.20           1.51       0.70
# std          97.39    10.58     2.90   61354.91           0.67       0.46
# min         350.00    18.00     0.00       0.00           1.00       0.00
# 25%         583.00    33.00     3.00       0.00           1.00       0.00
# 50%         651.00    40.00     5.00  103006.24           1.00       1.00
# 75%         718.00    47.00     8.00  129292.80           2.00       1.00
# max         850.00    88.00    10.00  250898.09           4.00       1.00
#
#        IsActiveMember  EstimatedSalary   Exited  Complain  Satisfaction Score  \
# count         4138.00          4138.00  4138.00   4138.00             4138.00
# mean             0.46        100773.86     0.49      0.49                2.98
# std              0.50         58052.49     0.50      0.50                1.41
# min              0.00            11.58     0.00      0.00                1.00
# 25%              0.00         50791.07     0.00      0.00                2.00
# 50%              0.00        102298.48     0.00      0.00                3.00
# 75%              1.00        150827.01     1.00      1.00                4.00
# max              1.00        199909.32     1.00      1.00                5.00
#
#        Point Earned
# count       4138.00
# mean         605.36
# std          224.07
# min          163.00
# 25%          407.00
# 50%          606.00
# 75%          798.00
# max         1000.00

# %%
newdf[newdf["Balance"]== 0]["Exited"].value_counts().reset_index()
# Out:
#    Exited  count
# 0       0    824
# 1       1    500

# %%
newdf[newdf["Balance"] > 0 ]["Exited"].value_counts().reset_index()
# Out:
#    Exited  count
# 0       1   1538
# 1       0   1276

# %%
df["Exited"].value_counts().reset_index()
# Out:
#    Exited  count
# 0       0   7962
# 1       1   2038

# %%
cat_col= df.select_dtypes(include=["object"])
cat_col
# Out:
#      Geography  Gender Card Type
# 0       France  Female   DIAMOND
# 1        Spain  Female   DIAMOND
# 2       France  Female   DIAMOND
# 3       France  Female      GOLD
# 4        Spain  Female      GOLD
# ...        ...     ...       ...
# 9995    France    Male   DIAMOND
# 9996    France    Male  PLATINUM
# 9997    France  Female    SILVER
# 9998   Germany    Male      GOLD
# 9999    France  Female   DIAMOND
#
# [10000 rows x 3 columns]

# %%
sns.catplot(x=df["Card Type"], kind="count")
sns.catplot(x=df["Gender"], kind="count")
sns.catplot(x=df["Geography"], kind="count")

# %%
num_col=df.select_dtypes(exclude=["object"])
num_col
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Complain  Satisfaction Score  \
# 0                  1        101348.88       1         1                   2
# 1                  1        112542.58       0         1                   3
# 2                  0        113931.57       1         1                   3
# 3                  0         93826.63       0         0                   5
# 4                  1         79084.10       0         0                   5
# ...              ...              ...     ...       ...                 ...
# 9995               0         96270.64       0         0                   1
# 9996               1        101699.77       0         0                   5
# 9997               1         42085.58       1         1                   3
# 9998               0         92888.52       1         1                   2
# 9999               0         38190.78       0         0                   3
#
#       Point Earned
# 0              464
# 1              456
# 2              377
# 3              350
# 4              425
# ...            ...
# 9995           300
# 9996           771
# 9997           564
# 9998           339
# 9999           911
#
# [10000 rows x 12 columns]

# %%
sns.boxplot(df["Balance"])
# Out:
# <Axes: ylabel='Balance'>

# %%
sns.histplot(data=df, x="Balance", hue="Exited")
# Out:
# <Axes: xlabel='Balance', ylabel='Count'>

# %%
sns.histplot(data= df, x="NumOfProducts")
df["NumOfProducts"].value_counts()
# Out:
# NumOfProducts
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: count, dtype: int64

# %%
sns.histplot(data= df, x="HasCrCard", hue="Exited")
df["HasCrCard"].value_counts().reset_index()
# Out:
#    HasCrCard  count
# 0          1   7055
# 1          0   2945

# %%
sns.histplot(data= df, x="IsActiveMember", hue= "Exited")
df["IsActiveMember"].value_counts().reset_index()
# Out:
#    IsActiveMember  count
# 0               1   5151
# 1               0   4849

# %%
sns.histplot(data= df, x="Complain", hue= "Exited")
df["Complain"].value_counts().reset_index()
# Out:
#    Complain  count
# 0         0   7956
# 1         1   2044

# %%
#df.pivot_table(index="Complain", columns="Exited", values="CustomerId", aggfunc="count")

# %%
sns.histplot(data= df, x="Satisfaction Score", hue= "Exited")
df["Satisfaction Score"].value_counts().reset_index()
# Out:
#    Satisfaction Score  count
# 0                   3   2042
# 1                   2   2014
# 2                   4   2008
# 3                   5   2004
# 4                   1   1932

# %%
sns.histplot(data= df, x="Point Earned", hue="Exited", shrink=1)
# Out:
# <Axes: xlabel='Point Earned', ylabel='Count'>
